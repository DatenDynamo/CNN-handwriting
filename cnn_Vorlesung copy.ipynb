# %% [markdown]
# # Convolutional Neural Network

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
import random
import pandas as pd
import matplotlib.pyplot as plt
import cv2 as cv

plt.gray()

# %%
print(f"TensorFlow version: {tf.__version__}")
print(f"Available GPUs: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow version: 2.15.0
# Available GPUs: []

# %% [markdown]
# ## 0 Helper function

# %%
def relu(x):
    return np.max([0.0,x])

# %%
def linear(x):
    return x

# %%
def conv(pic,conv_matrix,af=linear,bias=None):
    size_x_conv = conv_matrix.shape[0]
    size_y_conv = conv_matrix.shape[1]

    num_filters = conv_matrix.shape[2]
    
    len_x = pic.shape[0]-size_x_conv+1
    len_y = pic.shape[1]-size_y_conv+1

    num_lines = int(np.ceil(num_filters/10))

    fig = plt.figure(figsize=(20,num_lines*1.5))

    if bias is None:
        bias = np.zeros(num_filters)
    
    nplt = 1
    for f in range(num_filters):
        pic_conv = np.zeros((len_x,len_y))

        for i in range(len_x):
            for j in range(len_y):
                pic_conv[i,j] = af((pic[i:i+size_x_conv,j:j+size_y_conv]*conv_matrix[:,:,f]).sum()+bias[f])
            
        ax = fig.add_subplot(num_lines,10,nplt)
        ax.axis('off')
        ax.set_title(str(f))

        plt.imshow(pic_conv)
        nplt += 1
    return

# %%
def plot_samples(xdata,ydata,amount=40):
    for number in range(10):
        indeces = np.random.choice(np.where(ydata == number)[0],size=amount,replace=False)
        fig = plt.figure(figsize=(20,6))
        fig.suptitle("examples for number "+str(number)+":")
        nplt = 1
        for index in indeces:
            ax = fig.add_subplot(4,10,nplt)
            ax.axis('off')
            plt.imshow(xdata[index])
            nplt += 1

# %%
def rotate_image(image, rotation_angle=0, scale=1):
    height, width = image.shape
    M = cv.getRotationMatrix2D(((width - 1) / 2.0, (height - 1) / 2.0),
                               rotation_angle, scale)
    image_rotated = cv.warpAffine(np.squeeze(image), M, (width, height))

    return image_rotated

# %% [markdown]
# ## 1 MNIST dataset

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()

# %% [markdown]
# Normalizing the data:

# %%
x_train = x_train / 255
x_test = x_test / 255

# %% [markdown]
# ## 2 Building and Testing a CNN

# %% [markdown]
# ### 2.1 A simple CNN

# %% [markdown]
# #### 2.1.1 Training

# %%
def create_simple_model():
    model = tf.keras.models.Sequential()
    
    # feature extraction
    model.add(keras.layers.Conv2D(filters=32,
                    kernel_size=(3,3),
                    activation="relu",
                    input_shape=(28,28,1)))

    model.add(keras.layers.MaxPooling2D(pool_size=(3,3)))

    # Classification
    model.add(keras.layers.Flatten())

    model.add(keras.layers.Dense(units=64, activation="relu"))

    # output layer
    model.add(keras.layers.Dense(units=10, activation="softmax"))

    model.summary()

    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])
    
    return model

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Test different batch_sizes:

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=8,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.1428 - accuracy: 0.9576
# Epoch 2/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0546 - accuracy: 0.9833
# Epoch 3/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0373 - accuracy: 0.9886
# Epoch 4/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0262 - accuracy: 0.9918
# Epoch 5/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0190 - accuracy: 0.9937
# Epoch 6/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0153 - accuracy: 0.9948
# Epoch 7/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0116 - accuracy: 0.9962
# Epoch 8/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 9/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0085 - accuracy: 0.9971
# Epoch 10/10
# 7500/7500 [==============================] - 10s 1ms/step - loss: 0.0070 - accuracy: 0.9977

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=16,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.1681 - accuracy: 0.9498
# Epoch 2/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0604 - accuracy: 0.9814
# Epoch 3/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0424 - accuracy: 0.9867
# Epoch 4/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0309 - accuracy: 0.9907
# Epoch 5/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0232 - accuracy: 0.9927
# Epoch 6/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0174 - accuracy: 0.9945
# Epoch 7/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0136 - accuracy: 0.9956
# Epoch 8/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0110 - accuracy: 0.9964
# Epoch 9/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0093 - accuracy: 0.9970
# Epoch 10/10
# 3750/3750 [==============================] - 7s 2ms/step - loss: 0.0074 - accuracy: 0.9975

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=32,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1884 - accuracy: 0.9443
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0657 - accuracy: 0.9801
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0472 - accuracy: 0.9852
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0358 - accuracy: 0.9888
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0278 - accuracy: 0.9913
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0214 - accuracy: 0.9931
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0177 - accuracy: 0.9946
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0140 - accuracy: 0.9954
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0106 - accuracy: 0.9966
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0092 - accuracy: 0.9968

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=64,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2273 - accuracy: 0.9354
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0800 - accuracy: 0.9755
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0585 - accuracy: 0.9820
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0465 - accuracy: 0.9855
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.9883
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0318 - accuracy: 0.9901
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0263 - accuracy: 0.9916
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0217 - accuracy: 0.9930
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0179 - accuracy: 0.9944
# Epoch 10/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0150 - accuracy: 0.9952

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=128,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2952 - accuracy: 0.9173
# Epoch 2/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0988 - accuracy: 0.9707
# Epoch 3/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0725 - accuracy: 0.9782
# Epoch 4/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0563 - accuracy: 0.9831
# Epoch 5/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0476 - accuracy: 0.9862
# Epoch 6/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0399 - accuracy: 0.9880
# Epoch 7/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9892
# Epoch 8/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0299 - accuracy: 0.9906
# Epoch 9/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0256 - accuracy: 0.9922
# Epoch 10/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0239 - accuracy: 0.9928

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=256,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 235/235 [==============================] - 2s 8ms/step - loss: 0.3998 - accuracy: 0.8969
# Epoch 2/10
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1119 - accuracy: 0.9670
# Epoch 3/10
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0805 - accuracy: 0.9766
# Epoch 4/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0659 - accuracy: 0.9809
# Epoch 5/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0567 - accuracy: 0.9830
# Epoch 6/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0514 - accuracy: 0.9845
# Epoch 7/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0437 - accuracy: 0.9872
# Epoch 8/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0394 - accuracy: 0.9878
# Epoch 9/10
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0358 - accuracy: 0.9894
# Epoch 10/10
# 235/235 [==============================] - 2s 9ms/step - loss: 0.0327 - accuracy: 0.9906

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=512,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.5821 - accuracy: 0.8647
# Epoch 2/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1468 - accuracy: 0.9579
# Epoch 3/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.1015 - accuracy: 0.9707
# Epoch 4/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0808 - accuracy: 0.9768
# Epoch 5/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0682 - accuracy: 0.9800
# Epoch 6/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0595 - accuracy: 0.9827
# Epoch 7/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0527 - accuracy: 0.9847
# Epoch 8/10
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0482 - accuracy: 0.9859
# Epoch 9/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0433 - accuracy: 0.9874
# Epoch 10/10
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0399 - accuracy: 0.9881

# %%
tf.keras.backend.clear_session()
model1 = create_simple_model()
model1.fit(x_train,y_train,batch_size=1024,epochs=10)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2  (None, 8, 8, 32)          0
#  D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 64)                131136
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/10
# 59/59 [==============================] - 2s 25ms/step - loss: 0.8212 - accuracy: 0.7770
# Epoch 2/10
# 59/59 [==============================] - 2s 26ms/step - loss: 0.2585 - accuracy: 0.9243
# Epoch 3/10
# 59/59 [==============================] - 2s 26ms/step - loss: 0.1788 - accuracy: 0.9491
# Epoch 4/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.1351 - accuracy: 0.9620
# Epoch 5/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.1112 - accuracy: 0.9682
# Epoch 6/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0945 - accuracy: 0.9730
# Epoch 7/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0834 - accuracy: 0.9757
# Epoch 8/10
# 59/59 [==============================] - 2s 26ms/step - loss: 0.0751 - accuracy: 0.9778
# Epoch 9/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0672 - accuracy: 0.9805
# Epoch 10/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0606 - accuracy: 0.9823

# %% [markdown]
# Thus, we can see a good compromise might be a batch size of 32 or 64. Can depend on the hardware.

# %%
model1 = create_simple_model()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_2 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 64)                131136
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.fit(x_train,y_train,batch_size=64,epochs=10)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2337 - accuracy: 0.9323
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0756 - accuracy: 0.9772
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0543 - accuracy: 0.9841
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0422 - accuracy: 0.9869
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0350 - accuracy: 0.9896
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0282 - accuracy: 0.9915
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0242 - accuracy: 0.9924
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0187 - accuracy: 0.9945
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0155 - accuracy: 0.9952
# Epoch 10/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0130 - accuracy: 0.9961

# %% [markdown]
# Evaluate on test data:

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 964us/step - loss: 0.0489 - accuracy: 0.9870
# [0.0489264540374279, 0.9869999885559082]

# %% [markdown]
# "misusing" test data for validation:

# %%
for i in range(10):
    model1.fit(x_train,y_train,batch_size=64,epochs=1)
    model1.evaluate(x_test,y_test)
    print(" ")
# Out:
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0110 - accuracy: 0.9966
# 313/313 [==============================] - 0s 891us/step - loss: 0.0434 - accuracy: 0.9885
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0100 - accuracy: 0.9967
# 313/313 [==============================] - 0s 861us/step - loss: 0.0409 - accuracy: 0.9883
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0071 - accuracy: 0.9979
# 313/313 [==============================] - 0s 854us/step - loss: 0.0478 - accuracy: 0.9867
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0072 - accuracy: 0.9977
# 313/313 [==============================] - 0s 889us/step - loss: 0.0590 - accuracy: 0.9844
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0058 - accuracy: 0.9982
# 313/313 [==============================] - 0s 851us/step - loss: 0.0484 - accuracy: 0.9883
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0049 - accuracy: 0.9986
# 313/313 [==============================] - 0s 875us/step - loss: 0.0482 - accuracy: 0.9887
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0044 - accuracy: 0.9987
# 313/313 [==============================] - 0s 933us/step - loss: 0.0490 - accuracy: 0.9881
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0058 - accuracy: 0.9981
# 313/313 [==============================] - 0s 862us/step - loss: 0.0520 - accuracy: 0.9880
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0036 - accuracy: 0.9988
# 313/313 [==============================] - 0s 903us/step - loss: 0.0475 - accuracy: 0.9884
#
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9990
# 313/313 [==============================] - 0s 952us/step - loss: 0.0492 - accuracy: 0.9892

# %% [markdown]
# Thus, even the loss for the training data is decreasing but the loss on the test data is not getting better and might be even worse, which might be due to overfitting. Consequently, it is more useful to use a validation data set to stop learning when the loss on the validation data is getting worse.

# %% [markdown]
# Now with validation included within the fit method. This means a part of the data will be used for validation to check convergence and in order to pretend overfitting.

# %%
model2 = create_simple_model()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_6 (Dense)             (None, 64)                131136
#
#  dense_7 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2.fit(x_train,y_train,batch_size=64,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.2735 - accuracy: 0.9199 - val_loss: 0.1075 - val_accuracy: 0.9680
# Epoch 2/10
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0858 - accuracy: 0.9743 - val_loss: 0.0813 - val_accuracy: 0.9747
# Epoch 3/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0616 - accuracy: 0.9814 - val_loss: 0.0685 - val_accuracy: 0.9791
# Epoch 4/10
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0502 - accuracy: 0.9841 - val_loss: 0.0574 - val_accuracy: 0.9818
# Epoch 5/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0403 - accuracy: 0.9881 - val_loss: 0.0716 - val_accuracy: 0.9792
# Epoch 6/10
# 750/750 [==============================] - 2s 3ms/step - loss: 0.0338 - accuracy: 0.9893 - val_loss: 0.0553 - val_accuracy: 0.9833
# Epoch 7/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0284 - accuracy: 0.9910 - val_loss: 0.0605 - val_accuracy: 0.9831
# Epoch 8/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0228 - accuracy: 0.9932 - val_loss: 0.0584 - val_accuracy: 0.9833
# Epoch 9/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0531 - val_accuracy: 0.9844
# Epoch 10/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0160 - accuracy: 0.9952 - val_loss: 0.0518 - val_accuracy: 0.9853

# %%
model2.fit(x_train,y_train,batch_size=64,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0524 - val_accuracy: 0.9858
# Epoch 2/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0590 - val_accuracy: 0.9851
# Epoch 3/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.0602 - val_accuracy: 0.9847
# Epoch 4/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0576 - val_accuracy: 0.9864
# Epoch 5/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0608 - val_accuracy: 0.9859
# Epoch 6/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0606 - val_accuracy: 0.9863
# Epoch 7/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0655 - val_accuracy: 0.9858
# Epoch 8/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.0614 - val_accuracy: 0.9868
# Epoch 9/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0725 - val_accuracy: 0.9848
# Epoch 10/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0711 - val_accuracy: 0.9857

# %%
model2.fit(x_train,y_train,batch_size=64,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0037 - accuracy: 0.9989 - val_loss: 0.0669 - val_accuracy: 0.9865
# Epoch 2/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.0688 - val_accuracy: 0.9884
# Epoch 3/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0742 - val_accuracy: 0.9836
# Epoch 4/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0733 - val_accuracy: 0.9859
# Epoch 5/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0710 - val_accuracy: 0.9875
# Epoch 6/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0745 - val_accuracy: 0.9865
# Epoch 7/10
# 750/750 [==============================] - 3s 3ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0745 - val_accuracy: 0.9861
# Epoch 8/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0768 - val_accuracy: 0.9864
# Epoch 9/10
# 750/750 [==============================] - 3s 4ms/step - loss: 5.3237e-04 - accuracy: 0.9999 - val_loss: 0.0763 - val_accuracy: 0.9873
# Epoch 10/10
# 750/750 [==============================] - 3s 4ms/step - loss: 2.1652e-04 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9883

# %%
model2.fit(x_train,y_train,batch_size=64,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 3s 4ms/step - loss: 9.0901e-05 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9884
# Epoch 2/10
# 750/750 [==============================] - 3s 4ms/step - loss: 7.4765e-05 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9877
# Epoch 3/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0996 - val_accuracy: 0.9829
# Epoch 4/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0707 - val_accuracy: 0.9871
# Epoch 5/10
# 750/750 [==============================] - 3s 4ms/step - loss: 5.0495e-04 - accuracy: 0.9999 - val_loss: 0.0709 - val_accuracy: 0.9875
# Epoch 6/10
# 750/750 [==============================] - 3s 4ms/step - loss: 1.7672e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9877
# Epoch 7/10
# 750/750 [==============================] - 3s 4ms/step - loss: 7.6670e-05 - accuracy: 1.0000 - val_loss: 0.0745 - val_accuracy: 0.9883
# Epoch 8/10
# 750/750 [==============================] - 3s 4ms/step - loss: 5.1523e-05 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9881
# Epoch 9/10
# 750/750 [==============================] - 3s 4ms/step - loss: 3.8417e-05 - accuracy: 1.0000 - val_loss: 0.0777 - val_accuracy: 0.9885
# Epoch 10/10
# 750/750 [==============================] - 3s 4ms/step - loss: 2.9432e-05 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9887

# %% [markdown]
# look at the whole training data:

# %%
model2.evaluate(x_train,y_train)
# Out:
# 1875/1875 [==============================] - 2s 945us/step - loss: 0.0159 - accuracy: 0.9977
# [0.015906546264886856, 0.9977333545684814]

# %% [markdown]
# We can see, that the accuracy is decreasing at the end, because there is the validation data set used during the fit.

# %% [markdown]
# just look at the test data:

# %%
model2.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0682 - accuracy: 0.9892
# [0.0682368129491806, 0.9891999959945679]

# %% [markdown]
# **Note:** due to time constraints we are not doing a full converged training throughout the notebook.
#
# Now, we can save the final model for later use:

# %%
model2.save('model_simple')
# Out:
# INFO:tensorflow:Assets written to: model_simple/assets
# INFO:tensorflow:Assets written to: model_simple/assets

# %% [markdown]
# A model can be loaded with:
#
# model_load = keras.models.load_model('model_drop')

# %% [markdown]
# #### 2.1.2 Analyze wrong data

# %% [markdown]
# ##### look at false categorized numbers for training data:

# %%
pred_train = model2.predict(x_train)
# Out:
# 1875/1875 [==============================] - 1s 750us/step

# %%
wrong = [i for i in range(len(pred_train))  
         if pred_train[i].argmax() != y_train[i]]
print("number of wrong numbers:",len(wrong),". That is ",
      len(wrong)/len(pred_train)*100,"% of the data.")
# Out:
# number of wrong numbers: 136 . That is  0.22666666666666668 % of the data.

# %%
nsub = int(np.ceil(len(wrong)/10))

fig = plt.figure(figsize=(20,nsub*1.5))

nplt = 1

for index in wrong:
    ax = fig.add_subplot(nsub,10,nplt)
    ax.axis('off')
    ax.set_title(str(y_train[index])+' vs '+
                 str(pred_train[index].argmax()))
    plt.imshow(x_train[index])
    nplt += 1

# %% [markdown]
# look at the distrubtion:

# %%
for index in wrong:
    print(f"label: {y_train[index]:1}  prediction: {pred_train[index].argmax():1}",
          f"with max= {pred_train[index].max():.4f}",
          f"and 2nd largest: {np.sort(pred_train[index])[-2]:.4f}")
# Out:
# label: 6  prediction: 8 with max= 0.5896 and 2nd largest: 0.3992
# label: 7  prediction: 9 with max= 0.9847 and 2nd largest: 0.0151
# label: 3  prediction: 2 with max= 0.9983 and 2nd largest: 0.0017
# label: 0  prediction: 4 with max= 0.9620 and 2nd largest: 0.0380
# label: 6  prediction: 5 with max= 0.9951 and 2nd largest: 0.0049
# label: 5  prediction: 7 with max= 0.6922 and 2nd largest: 0.3075
# label: 2  prediction: 8 with max= 0.7354 and 2nd largest: 0.1321
# label: 6  prediction: 2 with max= 1.0000 and 2nd largest: 0.0000
# label: 2  prediction: 6 with max= 0.9627 and 2nd largest: 0.0338
# label: 3  prediction: 7 with max= 0.8684 and 2nd largest: 0.1316
# label: 6  prediction: 2 with max= 0.9324 and 2nd largest: 0.0676
# label: 9  prediction: 7 with max= 0.9947 and 2nd largest: 0.0051
# label: 7  prediction: 2 with max= 1.0000 and 2nd largest: 0.0000
# label: 9  prediction: 8 with max= 0.9491 and 2nd largest: 0.0449
# label: 1  prediction: 2 with max= 0.8787 and 2nd largest: 0.1210
# label: 8  prediction: 9 with max= 0.9915 and 2nd largest: 0.0065
# label: 8  prediction: 4 with max= 0.5847 and 2nd largest: 0.3830
# label: 8  prediction: 0 with max= 1.0000 and 2nd largest: 0.0000
# label: 8  prediction: 0 with max= 0.7286 and 2nd largest: 0.2704
# label: 4  prediction: 7 with max= 0.9343 and 2nd largest: 0.0656
# label: 3  prediction: 2 with max= 0.6262 and 2nd largest: 0.3738
# label: 5  prediction: 9 with max= 0.7310 and 2nd largest: 0.2689
# label: 3  prediction: 2 with max= 0.7851 and 2nd largest: 0.2149
# label: 1  prediction: 2 with max= 0.9836 and 2nd largest: 0.0164
# label: 6  prediction: 8 with max= 0.9593 and 2nd largest: 0.0390
# label: 6  prediction: 4 with max= 0.8571 and 2nd largest: 0.1429
# label: 6  prediction: 1 with max= 0.8897 and 2nd largest: 0.0827
# label: 1  prediction: 7 with max= 0.5467 and 2nd largest: 0.4533
# label: 0  prediction: 1 with max= 0.8161 and 2nd largest: 0.1286
# label: 9  prediction: 0 with max= 1.0000 and 2nd largest: 0.0000
# label: 8  prediction: 7 with max= 0.8030 and 2nd largest: 0.1968
# label: 9  prediction: 7 with max= 0.9859 and 2nd largest: 0.0141
# label: 3  prediction: 7 with max= 0.9945 and 2nd largest: 0.0040
# label: 3  prediction: 9 with max= 0.9789 and 2nd largest: 0.0186
# label: 3  prediction: 9 with max= 0.9997 and 2nd largest: 0.0003
# label: 6  prediction: 0 with max= 0.6746 and 2nd largest: 0.3254
# label: 8  prediction: 2 with max= 1.0000 and 2nd largest: 0.0000
# label: 9  prediction: 8 with max= 0.9717 and 2nd largest: 0.0274
# label: 9  prediction: 0 with max= 0.9995 and 2nd largest: 0.0005
# label: 5  prediction: 3 with max= 0.9314 and 2nd largest: 0.0646
# label: 3  prediction: 9 with max= 0.5906 and 2nd largest: 0.3112
# label: 9  prediction: 4 with max= 0.9999 and 2nd largest: 0.0001
# label: 9  prediction: 4 with max= 0.9527 and 2nd largest: 0.0473
# label: 4  prediction: 8 with max= 0.9902 and 2nd largest: 0.0098
# label: 2  prediction: 7 with max= 0.9992 and 2nd largest: 0.0005
# label: 5  prediction: 2 with max= 0.9935 and 2nd largest: 0.0064
# label: 4  prediction: 9 with max= 1.0000 and 2nd largest: 0.0000
# label: 8  prediction: 7 with max= 0.9646 and 2nd largest: 0.0354
# label: 2  prediction: 0 with max= 0.9578 and 2nd largest: 0.0212
# label: 7  prediction: 3 with max= 0.9968 and 2nd largest: 0.0028
# label: 5  prediction: 3 with max= 0.7463 and 2nd largest: 0.2537
# label: 2  prediction: 7 with max= 0.9993 and 2nd largest: 0.0007
# label: 2  prediction: 8 with max= 0.9983 and 2nd largest: 0.0017
# label: 5  prediction: 4 with max= 0.9768 and 2nd largest: 0.0232
# label: 8  prediction: 9 with max= 0.9583 and 2nd largest: 0.0417
# label: 0  prediction: 6 with max= 0.9339 and 2nd largest: 0.0422
# label: 4  prediction: 9 with max= 0.7748 and 2nd largest: 0.2252
# label: 3  prediction: 9 with max= 0.9836 and 2nd largest: 0.0107
# label: 8  prediction: 1 with max= 0.6426 and 2nd largest: 0.3574
# label: 9  prediction: 3 with max= 0.9358 and 2nd largest: 0.0318
# label: 1  prediction: 6 with max= 0.6308 and 2nd largest: 0.3692
# label: 5  prediction: 3 with max= 0.9151 and 2nd largest: 0.0848
# label: 8  prediction: 2 with max= 1.0000 and 2nd largest: 0.0000
# label: 2  prediction: 7 with max= 0.9843 and 2nd largest: 0.0149
# label: 8  prediction: 7 with max= 0.9916 and 2nd largest: 0.0078
# label: 5  prediction: 6 with max= 0.7044 and 2nd largest: 0.2956
# label: 8  prediction: 2 with max= 0.7116 and 2nd largest: 0.2884
# label: 5  prediction: 6 with max= 0.9978 and 2nd largest: 0.0020
# label: 3  prediction: 2 with max= 0.8878 and 2nd largest: 0.1122
# label: 9  prediction: 4 with max= 0.9998 and 2nd largest: 0.0002
# label: 5  prediction: 9 with max= 0.7404 and 2nd largest: 0.2595
# label: 6  prediction: 5 with max= 0.6499 and 2nd largest: 0.2470
# label: 5  prediction: 8 with max= 0.9777 and 2nd largest: 0.0223
# label: 9  prediction: 7 with max= 0.8094 and 2nd largest: 0.1906
# label: 2  prediction: 3 with max= 0.9721 and 2nd largest: 0.0279
# label: 8  prediction: 9 with max= 0.9999 and 2nd largest: 0.0001
# label: 8  prediction: 2 with max= 0.9625 and 2nd largest: 0.0273
# label: 2  prediction: 6 with max= 0.9919 and 2nd largest: 0.0081
# label: 8  prediction: 2 with max= 0.7165 and 2nd largest: 0.2710
# label: 3  prediction: 5 with max= 0.9999 and 2nd largest: 0.0001
# label: 7  prediction: 9 with max= 0.9372 and 2nd largest: 0.0626
# label: 4  prediction: 1 with max= 1.0000 and 2nd largest: 0.0000
# label: 3  prediction: 9 with max= 0.9568 and 2nd largest: 0.0432
# label: 1  prediction: 6 with max= 0.9993 and 2nd largest: 0.0007
# label: 1  prediction: 2 with max= 0.9998 and 2nd largest: 0.0002
# label: 2  prediction: 1 with max= 0.7646 and 2nd largest: 0.2347
# label: 3  prediction: 2 with max= 0.9930 and 2nd largest: 0.0062
# label: 3  prediction: 2 with max= 0.6128 and 2nd largest: 0.3872
# label: 4  prediction: 6 with max= 0.6118 and 2nd largest: 0.3813
# label: 4  prediction: 1 with max= 0.9982 and 2nd largest: 0.0018
# label: 8  prediction: 9 with max= 0.9959 and 2nd largest: 0.0041
# label: 9  prediction: 0 with max= 0.8472 and 2nd largest: 0.1528
# label: 5  prediction: 3 with max= 0.8237 and 2nd largest: 0.1720
# label: 4  prediction: 9 with max= 0.9921 and 2nd largest: 0.0078
# label: 5  prediction: 6 with max= 0.9990 and 2nd largest: 0.0008
# label: 9  prediction: 3 with max= 0.8168 and 2nd largest: 0.1823
# label: 7  prediction: 4 with max= 0.9999 and 2nd largest: 0.0001
# label: 5  prediction: 2 with max= 0.9457 and 2nd largest: 0.0542
# label: 4  prediction: 6 with max= 0.6394 and 2nd largest: 0.3592
# label: 5  prediction: 3 with max= 0.9397 and 2nd largest: 0.0603
# label: 3  prediction: 2 with max= 0.9979 and 2nd largest: 0.0020
# label: 7  prediction: 3 with max= 0.9932 and 2nd largest: 0.0068
# label: 4  prediction: 9 with max= 1.0000 and 2nd largest: 0.0000
# label: 4  prediction: 9 with max= 0.7375 and 2nd largest: 0.2584
# label: 0  prediction: 1 with max= 0.4312 and 2nd largest: 0.3109
# label: 9  prediction: 3 with max= 0.9573 and 2nd largest: 0.0374
# label: 5  prediction: 3 with max= 0.9248 and 2nd largest: 0.0752
# label: 4  prediction: 9 with max= 0.9990 and 2nd largest: 0.0009
# label: 8  prediction: 1 with max= 0.5136 and 2nd largest: 0.4863
# label: 9  prediction: 8 with max= 0.5493 and 2nd largest: 0.3390
# label: 5  prediction: 8 with max= 1.0000 and 2nd largest: 0.0000
# label: 8  prediction: 4 with max= 0.9964 and 2nd largest: 0.0023
# label: 0  prediction: 9 with max= 0.9999 and 2nd largest: 0.0001
# label: 5  prediction: 8 with max= 0.7863 and 2nd largest: 0.2137
# label: 8  prediction: 2 with max= 0.9839 and 2nd largest: 0.0161
# label: 0  prediction: 8 with max= 0.9989 and 2nd largest: 0.0011
# label: 5  prediction: 6 with max= 1.0000 and 2nd largest: 0.0000
# label: 9  prediction: 3 with max= 0.9028 and 2nd largest: 0.0971
# label: 0  prediction: 9 with max= 0.6906 and 2nd largest: 0.2784
# label: 4  prediction: 9 with max= 1.0000 and 2nd largest: 0.0000
# label: 1  prediction: 7 with max= 0.9997 and 2nd largest: 0.0002
# label: 7  prediction: 4 with max= 0.9888 and 2nd largest: 0.0112
# label: 8  prediction: 4 with max= 0.9999 and 2nd largest: 0.0001
# label: 5  prediction: 3 with max= 0.9990 and 2nd largest: 0.0007
# label: 3  prediction: 8 with max= 0.9956 and 2nd largest: 0.0044
# label: 6  prediction: 4 with max= 1.0000 and 2nd largest: 0.0000
# label: 0  prediction: 9 with max= 0.9994 and 2nd largest: 0.0005
# label: 5  prediction: 6 with max= 0.9992 and 2nd largest: 0.0008
# label: 8  prediction: 5 with max= 0.9813 and 2nd largest: 0.0187
# label: 9  prediction: 5 with max= 1.0000 and 2nd largest: 0.0000
# label: 2  prediction: 0 with max= 0.9903 and 2nd largest: 0.0051
# label: 7  prediction: 9 with max= 0.9947 and 2nd largest: 0.0053
# label: 5  prediction: 6 with max= 0.6893 and 2nd largest: 0.2707
# label: 5  prediction: 6 with max= 1.0000 and 2nd largest: 0.0000
# label: 5  prediction: 6 with max= 0.9924 and 2nd largest: 0.0042
# label: 4  prediction: 7 with max= 1.0000 and 2nd largest: 0.0000

# %% [markdown]
# now look at pictures again with 2nd largest alternative

# %%
nsub = int(np.ceil(len(wrong)/10))

fig = plt.figure(figsize=(20,nsub*1.5))

nplt = 1

for index in wrong:
    ax = fig.add_subplot(nsub,10,nplt)
    ax.axis('off')
    if np.sort(pred_train[index])[-2] > 0.2:
        mark='*'
    else:
        mark=''
    ax.set_title(str(y_train[index])+' vs '
                 +str(pred_train[index].argmax())
                 +'('+str(np.argsort(pred_train[index])[-2])+')'+mark)
    plt.imshow(x_train[index])
    nplt += 1

# %% [markdown]
# ##### now for the test data:

# %%
pred_test = model2.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 948us/step

# %%
wrong = [i for i in range(len(pred_test))  
         if pred_test[i].argmax() != y_test[i]]
print("number of wrong numbers:",len(wrong),
      ". That is ",len(wrong)/len(pred_test)*100,"% of the data.")
# Out:
# number of wrong numbers: 108 . That is  1.08 % of the data.

# %%
nsub = int(np.ceil(len(wrong)/10))

fig = plt.figure(figsize=(20,nsub*1.5))

nplt = 1

for index in wrong:
    ax = fig.add_subplot(nsub,10,nplt)
    ax.axis('off')
    ax.set_title(str(y_test[index])+' vs '
                 +str(pred_test[index].argmax()))
    plt.imshow(x_test[index])
    nplt += 1

# %% [markdown]
# #### 2.1.3 Analyze the conv filters

# %%
convm = model2.layers[0].get_weights()[0][:,:,0,:]
for i in [34,3,2,76,995]:
    conv(x_train[i],convm)

# %%
bias = model2.layers[0].get_weights()[1]

# %%
for i in [34,3,2,76,995]:
    conv(x_train[i],convm,af=relu,bias=-bias)

# %% [markdown]
# ### 2.2 CNN with dropout layer

# %% [markdown]
# Using a dropout layer to get better generalization.

# %%
def create_simple_dropout_model():
    model = tf.keras.models.Sequential()
    
    # feature extraction
    model.add(keras.layers.Conv2D(filters=32,
                    kernel_size=(3,3),
                    activation="relu",
                    input_shape=(28,28,1)))

    model.add(keras.layers.MaxPooling2D(pool_size=(3,3)))

    # Classification
    model.add(keras.layers.Flatten())

    model.add(keras.layers.Dropout(rate=0.5))

    model.add(keras.layers.Dense(units=64, activation="relu"))

    # output layer
    model.add(keras.layers.Dense(units=10, activation="softmax"))

    model.summary()

    model.compile(
        optimizer="adam", loss="sparse_categorical_crossentropy",
        metrics=["accuracy"])
    
    return model

# %%
model_drop = create_simple_dropout_model()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_4 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_8 (Dense)             (None, 64)                131136
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_drop.fit(x_train,y_train,batch_size=64,epochs=10,
               validation_split=0.2)
# Out:
# Epoch 1/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3732 - accuracy: 0.8852 - val_loss: 0.1332 - val_accuracy: 0.9595
# Epoch 2/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1499 - accuracy: 0.9538 - val_loss: 0.0818 - val_accuracy: 0.9768
# Epoch 3/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1118 - accuracy: 0.9651 - val_loss: 0.0663 - val_accuracy: 0.9806
# Epoch 4/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0910 - accuracy: 0.9721 - val_loss: 0.0613 - val_accuracy: 0.9828
# Epoch 5/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0781 - accuracy: 0.9762 - val_loss: 0.0501 - val_accuracy: 0.9850
# Epoch 6/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0711 - accuracy: 0.9781 - val_loss: 0.0496 - val_accuracy: 0.9843
# Epoch 7/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0621 - accuracy: 0.9809 - val_loss: 0.0463 - val_accuracy: 0.9863
# Epoch 8/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0567 - accuracy: 0.9818 - val_loss: 0.0424 - val_accuracy: 0.9877
# Epoch 9/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0534 - accuracy: 0.9833 - val_loss: 0.0438 - val_accuracy: 0.9869
# Epoch 10/10
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0468 - accuracy: 0.9847 - val_loss: 0.0390 - val_accuracy: 0.9883

# %%
model_drop.fit(x_train,y_train,batch_size=64,epochs=20,
               validation_split=0.2)
# Out:
# Epoch 1/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0421 - accuracy: 0.9865 - val_loss: 0.0369 - val_accuracy: 0.9891
# Epoch 2/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0409 - accuracy: 0.9870 - val_loss: 0.0344 - val_accuracy: 0.9901
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0373 - accuracy: 0.9879 - val_loss: 0.0350 - val_accuracy: 0.9893
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.0344 - val_accuracy: 0.9903
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0352 - accuracy: 0.9882 - val_loss: 0.0339 - val_accuracy: 0.9908
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.0340 - val_accuracy: 0.9909
# Epoch 7/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0289 - accuracy: 0.9903 - val_loss: 0.0327 - val_accuracy: 0.9908
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.0371 - val_accuracy: 0.9897
# Epoch 9/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.0365 - val_accuracy: 0.9898
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0267 - accuracy: 0.9911 - val_loss: 0.0359 - val_accuracy: 0.9908
# Epoch 11/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0231 - accuracy: 0.9925 - val_loss: 0.0370 - val_accuracy: 0.9901
# Epoch 12/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.0339 - val_accuracy: 0.9908
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0222 - accuracy: 0.9928 - val_loss: 0.0348 - val_accuracy: 0.9910
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0217 - accuracy: 0.9926 - val_loss: 0.0359 - val_accuracy: 0.9894
# Epoch 15/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.0352 - val_accuracy: 0.9907
# Epoch 16/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.0346 - val_accuracy: 0.9908
# Epoch 17/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.0394 - val_accuracy: 0.9898
# Epoch 18/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.0364 - val_accuracy: 0.9908
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0188 - accuracy: 0.9934 - val_loss: 0.0389 - val_accuracy: 0.9909
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.0361 - val_accuracy: 0.9908

# %% [markdown]
# We see that the fit on the validation set is better.

# %% [markdown]
# One can save a trained model (note: the model is not converged):

# %%
model_drop.save('model_drop')
# Out:
# INFO:tensorflow:Assets written to: model_drop/assets
# INFO:tensorflow:Assets written to: model_drop/assets

# %% [markdown]
# Evaluate training data and compare both CNNs:

# %%
model2.evaluate(x_train,y_train)
model_drop.evaluate(x_train,y_train)
# Out:
# 1875/1875 [==============================] - 2s 856us/step - loss: 0.0159 - accuracy: 0.9977
# 1875/1875 [==============================] - 2s 924us/step - loss: 0.0095 - accuracy: 0.9975
# [0.009513812139630318, 0.9975333213806152]

# %% [markdown]
# Note: the difference to the value during the fit is due to the dropout layer. With evaluate there is no dropout layer in condratiction to the fit.

# %% [markdown]
# Now we use the test data:

# %%
model2.evaluate(x_test,y_test)
model_drop.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0682 - accuracy: 0.9892
# 313/313 [==============================] - 0s 973us/step - loss: 0.0311 - accuracy: 0.9919
# [0.031140707433223724, 0.9919000267982483]

# %% [markdown]
# We see that the test case improved a bit (about 0.3% (depends on run)). Thus, the dropout layer will lead to a better generalization.

# %% [markdown]
# ### 2.3 Augmentation of data

# %% [markdown]
# #### 2.3.1 Translations

# %% [markdown]
# ##### 2.3.1.1 x-direction

# %%
x_train_moved_x = np.zeros(x_train.shape)
for i in range(len(x_train)):
    shift=np.random.randint(-5,6)
    for j in range(max(0,shift),min(28,28+shift)):
        x_train_moved_x[i,:,j]=x_train[i,:,j-shift]

# %%
plot_samples(x_train_moved_x,y_train)

# %%
model_drop.evaluate(x_train_moved_x,y_train)
# Out:
# 1875/1875 [==============================] - 1s 782us/step - loss: 1.1903 - accuracy: 0.7947
# [1.1903101205825806, 0.7947499752044678]

# %% [markdown]
# We see a strong decrease in correct classification just due to some small shifts in x-direction.
#
# Now do a new fitting using the moved data as well.

# %% [markdown]
# **Note:** tensorflow is using for the validation set just the last data samples. Thus, we need to shuffle the original and moved data in order to get no bias in the validation set:

# %%
x_train_all = np.concatenate([x_train,x_train_moved_x])
y_train_all = np.concatenate([y_train,y_train])
perm = np.random.permutation(len(x_train_all))

x_train_all = x_train_all[perm]
y_train_all = y_train_all[perm]

# %%
model_drop_move_x = create_simple_dropout_model()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_10 (Dense)            (None, 64)                131136
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_drop_move_x.fit(x_train_all,y_train_all,
          batch_size=64,epochs=20,validation_split=0.2)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.3455 - accuracy: 0.8963 - val_loss: 0.1242 - val_accuracy: 0.9649
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1426 - accuracy: 0.9558 - val_loss: 0.0797 - val_accuracy: 0.9758
# Epoch 3/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1078 - accuracy: 0.9667 - val_loss: 0.0637 - val_accuracy: 0.9807
# Epoch 4/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0868 - accuracy: 0.9723 - val_loss: 0.0560 - val_accuracy: 0.9821
# Epoch 5/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0729 - accuracy: 0.9768 - val_loss: 0.0532 - val_accuracy: 0.9835
# Epoch 6/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0673 - accuracy: 0.9785 - val_loss: 0.0451 - val_accuracy: 0.9869
# Epoch 7/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0598 - accuracy: 0.9804 - val_loss: 0.0476 - val_accuracy: 0.9856
# Epoch 8/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0545 - accuracy: 0.9825 - val_loss: 0.0390 - val_accuracy: 0.9887
# Epoch 9/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0511 - accuracy: 0.9833 - val_loss: 0.0377 - val_accuracy: 0.9885
# Epoch 10/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.0382 - val_accuracy: 0.9885
# Epoch 11/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0447 - accuracy: 0.9860 - val_loss: 0.0359 - val_accuracy: 0.9889
# Epoch 12/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0415 - accuracy: 0.9865 - val_loss: 0.0359 - val_accuracy: 0.9883
# Epoch 13/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0399 - accuracy: 0.9867 - val_loss: 0.0352 - val_accuracy: 0.9895
# Epoch 14/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0375 - accuracy: 0.9876 - val_loss: 0.0373 - val_accuracy: 0.9893
# Epoch 15/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0360 - accuracy: 0.9880 - val_loss: 0.0347 - val_accuracy: 0.9895
# Epoch 16/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0349 - accuracy: 0.9882 - val_loss: 0.0360 - val_accuracy: 0.9891
# Epoch 17/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 0.0336 - val_accuracy: 0.9892
# Epoch 18/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0321 - accuracy: 0.9892 - val_loss: 0.0364 - val_accuracy: 0.9895
# Epoch 19/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.0345 - val_accuracy: 0.9897
# Epoch 20/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 0.0333 - val_accuracy: 0.9908

# %% [markdown]
# Just evaluate the model on our different data sets:

# %%
model_drop_move_x.evaluate(x_train,y_train)
model_drop_move_x.evaluate(x_train_moved_x,y_train)
model_drop_move_x.evaluate(x_test,y_test)
# Out:
# 1875/1875 [==============================] - 1s 773us/step - loss: 0.0098 - accuracy: 0.9974
# 1875/1875 [==============================] - 1s 777us/step - loss: 0.0143 - accuracy: 0.9961
# 313/313 [==============================] - 0s 886us/step - loss: 0.0300 - accuracy: 0.9904
# [0.029968595132231712, 0.9904000163078308]

# %% [markdown]
# Now test with a new movement into x-direction (new in the sense of random):

# %%
x_train_moved_x2 = np.zeros(x_train.shape)
for i in range(len(x_train)):
    shift=np.random.randint(-5,6)
    for j in range(max(0,shift),min(28,28+shift)):
        x_train_moved_x2[i,:,j]=x_train[i,:,j-shift]

# %%
model_drop_move_x.evaluate(x_train_moved_x2,y_train)
# Out:
# 1875/1875 [==============================] - 1s 753us/step - loss: 0.0362 - accuracy: 0.9890
# [0.0361560620367527, 0.9890499711036682]

# %% [markdown]
# This seems to work fine.

# %% [markdown]
# ##### 2.3.1.2 y-direction

# %% [markdown]
# Now make a movement into the y-direction:

# %%
x_train_moved_y = np.zeros(x_train.shape)
for i in range(len(x_train)):
    shift=np.random.randint(-5,6)
    for j in range(max(0,shift),min(28,28+shift)):
        x_train_moved_y[i,j,:]=x_train[i,j-shift,:]

# %%
model_drop.evaluate(x_train_moved_y,y_train)
model_drop_move_x.evaluate(x_train_moved_y,y_train)
# Out:
# 1875/1875 [==============================] - 2s 805us/step - loss: 2.2245 - accuracy: 0.6984
# 1875/1875 [==============================] - 2s 840us/step - loss: 2.1351 - accuracy: 0.7080
# [2.135146141052246, 0.707966685295105]

# %% [markdown]
# This looks really bad. Now make a new fit of the network including movement in y-direction:

# %%
x_train_all = np.concatenate([x_train,x_train_moved_x,x_train_moved_y])
y_train_all = np.concatenate([y_train,y_train,y_train])
perm = np.random.permutation(len(x_train_all))

x_train_all = x_train_all[perm]
y_train_all = y_train_all[perm]

# %%
model_drop_move_x.fit(x_train_all,y_train_all,
          batch_size=64,epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 2250/2250 [==============================] - 9s 4ms/step - loss: 0.1324 - accuracy: 0.9606 - val_loss: 0.0522 - val_accuracy: 0.9845
# Epoch 2/10
# 2250/2250 [==============================] - 9s 4ms/step - loss: 0.0803 - accuracy: 0.9744 - val_loss: 0.0452 - val_accuracy: 0.9860
# Epoch 3/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0699 - accuracy: 0.9776 - val_loss: 0.0396 - val_accuracy: 0.9875
# Epoch 4/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0627 - accuracy: 0.9797 - val_loss: 0.0408 - val_accuracy: 0.9865
# Epoch 5/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0600 - accuracy: 0.9807 - val_loss: 0.0388 - val_accuracy: 0.9878
# Epoch 6/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0547 - accuracy: 0.9822 - val_loss: 0.0380 - val_accuracy: 0.9879
# Epoch 7/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0518 - accuracy: 0.9828 - val_loss: 0.0361 - val_accuracy: 0.9886
# Epoch 8/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0503 - accuracy: 0.9834 - val_loss: 0.0337 - val_accuracy: 0.9894
# Epoch 9/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0473 - accuracy: 0.9843 - val_loss: 0.0346 - val_accuracy: 0.9894
# Epoch 10/10
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.0458 - accuracy: 0.9851 - val_loss: 0.0368 - val_accuracy: 0.9883

# %% [markdown]
# **Note:** training is not converged yet.
#
# Now test with all our datasets:

# %%
model_drop_move_x.evaluate(x_train,y_train)
model_drop_move_x.evaluate(x_train_moved_x,y_train)
model_drop_move_x.evaluate(x_train_moved_y,y_train)
model_drop_move_x.evaluate(x_test,y_test)
# Out:
# 1875/1875 [==============================] - 1s 791us/step - loss: 0.0097 - accuracy: 0.9970
# 1875/1875 [==============================] - 2s 847us/step - loss: 0.0150 - accuracy: 0.9954
# 1875/1875 [==============================] - 1s 755us/step - loss: 0.0290 - accuracy: 0.9912
# 313/313 [==============================] - 0s 738us/step - loss: 0.0294 - accuracy: 0.9916
# [0.029366472736001015, 0.991599977016449]

# %% [markdown]
# Now test this with a new movement in y-direction:

# %%
x_train_moved_y2 = np.zeros(x_train.shape)
for i in range(len(x_train)):
    shift=np.random.randint(-5,6)
    for j in range(max(0,shift),min(28,28+shift)):
        x_train_moved_y2[i,j,:]=x_train[i,j-shift,:]

# %%
model_drop_move_x.evaluate(x_train_moved_y2,y_train)
# Out:
# 1875/1875 [==============================] - 2s 880us/step - loss: 0.0561 - accuracy: 0.9831
# [0.056114498525857925, 0.9830999970436096]

# %% [markdown]
# ##### 2.3.1.3 Arbitrary direction

# %% [markdown]
# Now making a translation in x- and y-direction:

# %%
x_train_moved_all = np.zeros(x_train.shape)
for i in range(len(x_train)):
    shiftx=np.random.randint(-5,6)
    shifty=np.random.randint(-5,6)
    for j in range(max(0,shifty),min(28,28+shifty)):
        for k in range(max(0,shiftx),min(28,28+shiftx)):
            x_train_moved_all[i,j,k]=x_train[i,j-shifty,k-shiftx]

# %%
plot_samples(x_train_moved_all,y_train)

# %%
model_drop_move_x.evaluate(x_train_moved_all,y_train)
# Out:
# 1875/1875 [==============================] - 2s 900us/step - loss: 0.4120 - accuracy: 0.8996
# [0.41201546788215637, 0.8996166586875916]

# %% [markdown]
# Not perfect, but better. Fit with these general translations might be needed.

# %%
x_train_all = np.concatenate([x_train,x_train_moved_all])
y_train_all = np.concatenate([y_train,y_train])
perm = np.random.permutation(len(x_train_all))

x_train_all = x_train_all[perm]
y_train_all = y_train_all[perm]

# %%
model_drop_move = create_simple_dropout_model()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_6 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 2048)              0
#
#  dropout_2 (Dropout)         (None, 2048)              0
#
#  dense_12 (Dense)            (None, 64)                131136
#
#  dense_13 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_drop_move.fit(x_train_all,y_train_all,
          batch_size=64,epochs=20,validation_split=0.2)
# Out:
# Epoch 1/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.6154 - accuracy: 0.8041 - val_loss: 0.2428 - val_accuracy: 0.9299
# Epoch 2/20
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.2690 - accuracy: 0.9151 - val_loss: 0.1671 - val_accuracy: 0.9501
# Epoch 3/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.2019 - accuracy: 0.9378 - val_loss: 0.1360 - val_accuracy: 0.9592
# Epoch 4/20
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.1698 - accuracy: 0.9465 - val_loss: 0.1112 - val_accuracy: 0.9663
# Epoch 5/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1472 - accuracy: 0.9536 - val_loss: 0.1079 - val_accuracy: 0.9666
# Epoch 6/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1319 - accuracy: 0.9586 - val_loss: 0.0886 - val_accuracy: 0.9729
# Epoch 7/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1222 - accuracy: 0.9616 - val_loss: 0.0845 - val_accuracy: 0.9737
# Epoch 8/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1110 - accuracy: 0.9651 - val_loss: 0.0822 - val_accuracy: 0.9752
# Epoch 9/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1052 - accuracy: 0.9669 - val_loss: 0.0793 - val_accuracy: 0.9756
# Epoch 10/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.1010 - accuracy: 0.9676 - val_loss: 0.0739 - val_accuracy: 0.9772
# Epoch 11/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0958 - accuracy: 0.9694 - val_loss: 0.0718 - val_accuracy: 0.9780
# Epoch 12/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0880 - accuracy: 0.9717 - val_loss: 0.0690 - val_accuracy: 0.9787
# Epoch 13/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0859 - accuracy: 0.9719 - val_loss: 0.0689 - val_accuracy: 0.9790
# Epoch 14/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0828 - accuracy: 0.9734 - val_loss: 0.0656 - val_accuracy: 0.9806
# Epoch 15/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0801 - accuracy: 0.9739 - val_loss: 0.0669 - val_accuracy: 0.9798
# Epoch 16/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0747 - accuracy: 0.9753 - val_loss: 0.0635 - val_accuracy: 0.9813
# Epoch 17/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0731 - accuracy: 0.9758 - val_loss: 0.0669 - val_accuracy: 0.9795
# Epoch 18/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0728 - accuracy: 0.9764 - val_loss: 0.0667 - val_accuracy: 0.9806
# Epoch 19/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0693 - accuracy: 0.9770 - val_loss: 0.0632 - val_accuracy: 0.9810
# Epoch 20/20
# 1500/1500 [==============================] - 7s 5ms/step - loss: 0.0661 - accuracy: 0.9779 - val_loss: 0.0652 - val_accuracy: 0.9816

# %% [markdown]
# Now test on all our datasets:

# %%
model_drop_move.evaluate(x_train,y_train)
model_drop_move.evaluate(x_train_moved_all,y_train)
model_drop_move.evaluate(x_train_moved_x,y_train)
model_drop_move.evaluate(x_train_moved_y,y_train)
model_drop_move.evaluate(x_test,y_test)
# Out:
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0179 - accuracy: 0.9944
# 1875/1875 [==============================] - 2s 933us/step - loss: 0.0432 - accuracy: 0.9883
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.0590 - accuracy: 0.9818
# 1875/1875 [==============================] - 2s 943us/step - loss: 0.0775 - accuracy: 0.9778
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 0.9904
# [0.03260023891925812, 0.9904000163078308]

# %% [markdown]
# Looks like the general movement is also good for the pure x- and y-direction.

# %%
model_drop_move.save('model_drop_move')
# Out:
# INFO:tensorflow:Assets written to: model_drop_move/assets
# INFO:tensorflow:Assets written to: model_drop_move/assets

# %% [markdown]
# #### 2.3.2 Rotations

# %% [markdown]
# We will rotate randomly betwenn -30 and 30 degrees.

# %%
x_train_rotate = np.zeros(x_train.shape)
for i in range(len(x_train)):
    x_train_rotate[i,:,:]=rotate_image(x_train[i],
                    rotation_angle=np.random.randint(-30,31))

# %%
plot_samples(x_train_rotate,y_train)

# %%
model_drop_move.evaluate(x_train,y_train)
model_drop_move.evaluate(x_train_rotate,y_train)
# Out:
# 1875/1875 [==============================] - 2s 945us/step - loss: 0.0179 - accuracy: 0.9944
# 1875/1875 [==============================] - 2s 952us/step - loss: 0.2201 - accuracy: 0.9355
# [0.22009089589118958, 0.9355000257492065]

# %% [markdown]
# Finally include everything in the fit:

# %%
x_train_all = np.concatenate([x_train,x_train_moved_all,
                              x_train_rotate])
y_train_all = np.concatenate([y_train,y_train,y_train])
perm = np.random.permutation(len(x_train_all))

x_train_all = x_train_all[perm]
y_train_all = y_train_all[perm]

# %%
model_drop_full = create_simple_dropout_model()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 32)          0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense_14 (Dense)            (None, 64)                131136
#
#  dense_15 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 132106 (516.04 KB)
# Trainable params: 132106 (516.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_drop_full.fit(x_train_all,y_train_all,
          batch_size=64,epochs=20,validation_split=0.2)
# Out:
# Epoch 1/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.5038 - accuracy: 0.8405 - val_loss: 0.1958 - val_accuracy: 0.9411
# Epoch 2/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.2216 - accuracy: 0.9312 - val_loss: 0.1379 - val_accuracy: 0.9582
# Epoch 3/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.1693 - accuracy: 0.9465 - val_loss: 0.1113 - val_accuracy: 0.9661
# Epoch 4/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.1437 - accuracy: 0.9544 - val_loss: 0.0979 - val_accuracy: 0.9707
# Epoch 5/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.1276 - accuracy: 0.9594 - val_loss: 0.0884 - val_accuracy: 0.9739
# Epoch 6/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.1178 - accuracy: 0.9627 - val_loss: 0.0817 - val_accuracy: 0.9751
# Epoch 7/20
# 2250/2250 [==============================] - 10s 4ms/step - loss: 0.1087 - accuracy: 0.9658 - val_loss: 0.0850 - val_accuracy: 0.9736
# Epoch 8/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.1007 - accuracy: 0.9678 - val_loss: 0.0820 - val_accuracy: 0.9743
# Epoch 9/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0958 - accuracy: 0.9689 - val_loss: 0.0752 - val_accuracy: 0.9771
# Epoch 10/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0919 - accuracy: 0.9699 - val_loss: 0.0703 - val_accuracy: 0.9786
# Epoch 11/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0870 - accuracy: 0.9719 - val_loss: 0.0720 - val_accuracy: 0.9775
# Epoch 12/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0851 - accuracy: 0.9724 - val_loss: 0.0690 - val_accuracy: 0.9791
# Epoch 13/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0830 - accuracy: 0.9733 - val_loss: 0.0669 - val_accuracy: 0.9796
# Epoch 14/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0797 - accuracy: 0.9742 - val_loss: 0.0707 - val_accuracy: 0.9789
# Epoch 15/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0775 - accuracy: 0.9746 - val_loss: 0.0657 - val_accuracy: 0.9809
# Epoch 16/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0746 - accuracy: 0.9756 - val_loss: 0.0657 - val_accuracy: 0.9801
# Epoch 17/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0734 - accuracy: 0.9766 - val_loss: 0.0659 - val_accuracy: 0.9803
# Epoch 18/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0704 - accuracy: 0.9769 - val_loss: 0.0658 - val_accuracy: 0.9807
# Epoch 19/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0710 - accuracy: 0.9769 - val_loss: 0.0666 - val_accuracy: 0.9800
# Epoch 20/20
# 2250/2250 [==============================] - 10s 5ms/step - loss: 0.0699 - accuracy: 0.9771 - val_loss: 0.0639 - val_accuracy: 0.9814

# %% [markdown]
# Now test on all our datasets:

# %%
model_drop_full.evaluate(x_train,y_train)
model_drop_full.evaluate(x_train_moved_x, y_train)
model_drop_full.evaluate(x_train_moved_y, y_train)
model_drop_full.evaluate(x_train_moved_all, y_train)
model_drop_full.evaluate(x_train_rotate,y_train)
model_drop_full.evaluate(x_test,y_test)
# Out:
# 1875/1875 [==============================] - 2s 952us/step - loss: 0.0162 - accuracy: 0.9952
# 1875/1875 [==============================] - 2s 914us/step - loss: 0.0639 - accuracy: 0.9808
# 1875/1875 [==============================] - 2s 911us/step - loss: 0.0781 - accuracy: 0.9767
# 1875/1875 [==============================] - 2s 854us/step - loss: 0.0480 - accuracy: 0.9863
# 1875/1875 [==============================] - 2s 894us/step - loss: 0.0326 - accuracy: 0.9906
# 313/313 [==============================] - 0s 964us/step - loss: 0.0314 - accuracy: 0.9904
# [0.03142683580517769, 0.9904000163078308]

# %%
model_drop_full.save('model_drop_full')
# Out:
# INFO:tensorflow:Assets written to: model_drop_full/assets
# INFO:tensorflow:Assets written to: model_drop_full/assets

# %% [markdown]
# ### 2.4 Comparison of all 4 models

# %% [markdown]
# Test our models (**note:** the models are not converged):

# %%
model2.evaluate(x_test,y_test)
model_drop.evaluate(x_test,y_test)
model_drop_move.evaluate(x_test,y_test)
model_drop_full.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0682 - accuracy: 0.9892
# 313/313 [==============================] - 0s 956us/step - loss: 0.0311 - accuracy: 0.9919
# 313/313 [==============================] - 0s 920us/step - loss: 0.0326 - accuracy: 0.9904
# 313/313 [==============================] - 0s 994us/step - loss: 0.0314 - accuracy: 0.9904
# [0.03142683580517769, 0.9904000163078308]

# %% [markdown]
# Save all 4 Models

# %%
model2.save('model2.h5',overwrite=True)
model_drop.save('model_drop.h5',overwrite=True)
model_drop_move.save('model_drop_move.h5',overwrite=True)
model_drop_full.save('model_drop_full.h5',overwrite=True)
